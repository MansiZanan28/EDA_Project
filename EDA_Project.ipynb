# %%
#Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load Dataset
df = pd.read_csv(r"/content/Lung_Cancer_Trends_Realistic.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Patient_ID                 3000 non-null   object
#  1   Age                        3000 non-null   int64
#  2   Gender                     3000 non-null   object
#  3   Smoking_Status             3000 non-null   object
#  4   Years_Smoking              3000 non-null   int64
#  5   Cigarettes_Per_Day         3000 non-null   int64
#  6   Secondhand_Smoke_Exposure  3000 non-null   object
#  7   Occupation_Exposure        2256 non-null   object
#  8   Air_Pollution_Level        3000 non-null   object
#  9   Family_History             3000 non-null   object
#  10  Genetic_Markers_Positive   3000 non-null   object
#  11  BMI                        3000 non-null   float64
#  12  Physical_Activity_Level    3000 non-null   object
# ...

# %%
df.head()
# Out:
#   Patient_ID  Age  Gender Smoking_Status  Years_Smoking  Cigarettes_Per_Day  \
# 0    P100000   76  Female          Never              6                  37
# 1    P100001   39    Male          Never             30                  39
# 2    P100002   85    Male         Former             47                  14
# 3    P100003   45  Female        Current             45                  32
# 4    P100004   48  Female          Never             46                  26
#
#   Secondhand_Smoke_Exposure Occupation_Exposure Air_Pollution_Level  \
# 0                       Low        Diesel Fumes                 Low
# 1                       Low              Silica                 Low
# 2                      High            Asbestos                 Low
# 3                    Medium              Silica                High
# 4                    Medium              Silica                 Low
#
#   Family_History  ... Diet_Quality  Region Income_Level Education_Level  \
# ...

# %%
#Missing Values:
df.isnull().sum()
df.dropna(inplace=True)

# %%
#Summary Statistics
df.describe()
# Out:
#               Age  Years_Smoking  Cigarettes_Per_Day         BMI  \
# count  301.000000     301.000000          301.000000  301.000000
# mean    58.468439      23.013289           19.644518   25.323920
# std     18.897526      13.692084           11.322097    4.979822
# min     25.000000       0.000000            0.000000   12.200000
# 25%     42.000000      11.000000           10.000000   22.300000
# 50%     59.000000      22.000000           20.000000   25.300000
# 75%     75.000000      34.000000           29.000000   28.400000
# max     89.000000      49.000000           39.000000   40.700000
#
#        Diagnosis_Year
# count      301.000000
# mean      2012.348837
# std          7.275615
# min       2000.000000
# 25%       2006.000000
# 50%       2013.000000
# 75%       2018.000000
# max       2024.000000

# %%
#Check for Duplicates:
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
#Shape
df.shape
# Out:
# (301, 24)

# %%
#Mean
df.mean(numeric_only=True)
# Out:
# Patient_ID                    150.000000
# Age                            58.468439
# Gender                          0.504983
# Smoking_Status                  0.916944
# Years_Smoking                  23.013289
# Cigarettes_Per_Day             19.644518
# Secondhand_Smoke_Exposure       0.996678
# Occupation_Exposure             0.970100
# Air_Pollution_Level             0.996678
# Family_History                  0.488372
# Genetic_Markers_Positive        0.079734
# BMI                            25.323920
# Physical_Activity_Level         1.023256
# Alcohol_Consumption             0.498339
# Diet_Quality                    0.963455
# Region                          1.461794
# Income_Level                    1.003322
# Education_Level                 1.046512
# Access_to_Healthcare            0.980066
# Screening_Frequency             1.073090
# Chronic_Lung_Disease            0.202658
# Lung_Cancer_Stage               1.491694
# Diagnosis_Year               2012.348837
# ...

# %%
#Median
df.median(numeric_only=True)
# Out:
# Patient_ID                    150.0
# Age                            59.0
# Gender                          1.0
# Smoking_Status                  1.0
# Years_Smoking                  22.0
# Cigarettes_Per_Day             20.0
# Secondhand_Smoke_Exposure       1.0
# Occupation_Exposure             1.0
# Air_Pollution_Level             1.0
# Family_History                  0.0
# Genetic_Markers_Positive        0.0
# BMI                            25.3
# Physical_Activity_Level         1.0
# Alcohol_Consumption             0.0
# Diet_Quality                    1.0
# Region                          1.0
# Income_Level                    1.0
# Education_Level                 1.0
# Access_to_Healthcare            1.0
# Screening_Frequency             1.0
# Chronic_Lung_Disease            0.0
# Lung_Cancer_Stage               1.0
# Diagnosis_Year               2013.0
# Survival_Status                 0.0
# dtype: float64

# %%
df.mode().iloc[0]
# Out:
# Patient_ID                      0.0
# Age                            37.0
# Gender                          1.0
# Smoking_Status                  0.0
# Years_Smoking                  15.0
# Cigarettes_Per_Day             21.0
# Secondhand_Smoke_Exposure       1.0
# Occupation_Exposure             1.0
# Air_Pollution_Level             0.0
# Family_History                  0.0
# Genetic_Markers_Positive        0.0
# BMI                            25.4
# Physical_Activity_Level         1.0
# Alcohol_Consumption             0.0
# Diet_Quality                    0.0
# Region                          0.0
# Income_Level                    1.0
# Education_Level                 1.0
# Access_to_Healthcare            0.0
# Screening_Frequency             1.0
# Chronic_Lung_Disease            0.0
# Lung_Cancer_Stage               1.0
# Diagnosis_Year               2017.0
# Survival_Status                 0.0
# Name: 0, dtype: float64

# %%
#Univariate Analysis:
plt.figure(figsize=(8, 5))
df['Age'].hist(bins=20, color='purple', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(False)
plt.show()

# %% [markdown]
# **Insight from above visualization:**
#  The age distribution likely has a peak around middle age (40–60 years), suggesting most lung cancer patients are in this range.
#
# Middle-aged to older adults are at higher risk of lung cancer.

# %%
#Bivariate Analysis
plt.figure(figsize=(8, 5))
sns.scatterplot(x='Age', y='Years_Smoking', data=df, hue='Gender', palette='coolwarm')
plt.title('Age vs Years Smoked by Gender')
plt.xlabel('Age')
plt.ylabel('Years Smoked')
plt.show()

# %% [markdown]
# **Insight from above visualization**: Older people tend to have smoked for longer periods.
#
# Smoking duration increases with age.

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Gender', y='Age', data=df)
plt.title('Age Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# **Insight from above visualization**: Lung cancer impacts male gender more dominantly compared to females.

# %%
#Heatmap- Heatmap of a crosstab shows survival counts for each gender.
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
